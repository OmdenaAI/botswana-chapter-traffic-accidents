# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# Read the data and show all tabs
df_excel = pd.read_excel('Transport & Infrastructure Statistics Report 2021.xlsx', sheet_name=None)
df_excel.keys()
# Out:
# dict_keys(['Page 1 table1', 'Page 2 table1', 'Page 3 table1', 'Page 4 table1', 'Page 5 table1', 'Page 6 table1', 'Page 7 table1', 'Page 8 table1', 'Page 9 table1', 'Page 10 table1', 'Page 11 table1', 'Page 12 table1', 'Page 13 table1', 'Page 14 table1', 'Page 15 table1', 'Page 16 table1', 'Page 17 table1', 'Page 18 table1', 'Page 19 table1', 'Page 20 table1', 'Page 21 table1', 'Page 22 table1', 'Page 23 table1', 'Page 24 table1', 'Page 25 table1', 'Page 26 table1', 'Page 27 table1', 'Page 28 table1', 'Page 29 table1', 'Page 30 table1', 'Page 31 table1', 'Page 32 table1', 'Page 33 table1', 'Page 34 table1', 'Page 35 table1', 'Page 36 table1', 'Page 37 table1', 'Page 38 table1', 'Page 39 table1', 'Page 40 table1', 'Page 41 table1', 'Page 42 table1', 'Page 43 table1', 'Page 44 table1', 'Page 45 table1', 'Page 46 table1', 'Page 47 table1', 'Page 48 table1', 'Page 49 table1', 'Page 50 table1', 'Page 51 table1', 'Page 52 table1', 'Page 53 table1', 'Page 54 table1', 'Page 55 table1', 'Page 
# ...

# %%
import re
# Create different dataframes for each tab
#for key, value in df_excel.items():
    #globals()[key] = value # this creates a new dataframe for each tab


# Arrange the dataframes column names and titles
for key, value in df_excel.items():
    if len(value.index) > 2: # check if the dataframe has more than one row
        value.columns = value.iloc[2] # set the second row as the column names
        value = value.drop(value.index[2]) # drop the second row
        value = value.reset_index(drop=True)
    globals()[key] = value


# Display the first 5 rows of each dataframe
for key, value in df_excel.items():
    print(key)
    print(value.head())
    print('\n')

# Display the column names of each dataframe
for key, value in df_excel.items():
    print(key)
    print(value.columns)
    print('\n')
# Out:
# Page 1 table1
# 2  2  \
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4
#
# 2 Private Bag 0024, Gaborone Private Bag F193, Private Bag 32 Private Bag 47
# 0                         Transport & Infrastructure
# 1                             Statistics Report 2021
# 2  Private Bag 0024, Gaborone Private Bag F193, P...
# 3  Tel: 3671300 Fax: 3952201 Francistown Ghanzi Maun
# 4  Toll Free: 0800 600 200 Tel: 241 5848  Fax: 24...
#
#
# Page 2 table1
# 1  1      Statistics Report 2021
# 0  0  Transport & Infrastructure
# 1  1      Statistics Report 2021
#
#
# Page 3 table1
# 2  2         Private Bag 0024,
# 0  0              Published by
# 1  1       Statistics Botswana
# 2  2         Private Bag 0024,
# 3  3                  Gaborone
# 4  4  Telephone: +267 367 1300
#
#
# Page 4 table1
# 2  2                                  TABLE OF CONTENTS
# 0  0                                                 i.
# 1  1  Transport & Infrastructure Statistics Report 2021
# ...
