# %%
import pandas as pd
import numpy as np

# %%
gdp = pd.read_csv("botswana-gdp-gross-domestic-product.csv", skiprows=16)
gdp.head()
# Out:
#          date   GDP ( Billions of US $)   Per Capita (US $)   Annual % Change
# 0  1960-12-31                  0.030412             59.2989               NaN
# 1  1961-12-31                  0.032902             62.7425            6.3433
# 2  1962-12-31                  0.035643             66.4455            6.6667
# 3  1963-12-31                  0.038091             69.3776            5.9210
# 4  1964-12-31                  0.041614             74.0101            6.8323

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   date                      62 non-null     object
#  1    GDP ( Billions of US $)  62 non-null     float64
#  2    Per Capita (US $)        62 non-null     float64
#  3    Annual % Change          61 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 2.1+ KB

# %%
gdp.describe()
# Out:
#         GDP ( Billions of US $)   Per Capita (US $)   Annual % Change
# count                 62.000000           62.000000         61.000000
# mean                   5.351144         2763.169152          7.680267
# std                    5.747540         2409.340814          6.733371
# min                    0.030412           59.298900        -14.144200
# 25%                    0.359382          486.018425          4.556600
# 50%                    3.866680         2829.267000          7.030400
# 75%                    9.919096         5091.755075         11.102800
# max                   17.614791         7080.812800         26.361900

# %%
gdp.to_csv("botswana-gdp-gross-domestic-product_processed.csv", index = False)

# %%
inflation = pd.read_csv("botswana-inflation-rate-cpi.csv", skiprows = 16)
inflation.head()
# Out:
#          date   Inflation Rate (%)   Annual Change
# 0  1975-12-31              11.9748             NaN NaN
# 1  1976-12-31              11.7324           -0.24 NaN
# 2  1977-12-31              13.1687            1.44 NaN
# 3  1978-12-31               9.0440           -4.12 NaN
# 4  1979-12-31              11.7362            2.69 NaN

# %%
inflation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 47 non-null     object
#  1    Inflation Rate (%)  47 non-null     float64
#  2    Annual Change       46 non-null     float64
#  3                        0 non-null      float64
# dtypes: float64(3), object(1)
# memory usage: 1.6+ KB

# %%
inflation.drop(inflation.columns[3], axis = 1, inplace = True)

# %%
inflation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 47 non-null     object
#  1    Inflation Rate (%)  47 non-null     float64
#  2    Annual Change       46 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.2+ KB

# %%
inflation.describe()
# Out:
#         Inflation Rate (%)   Annual Change
# count            47.000000       46.000000
# mean              8.904826       -0.102391
# std               3.443028        2.447865
# min               1.890400       -5.290000
# 25%               7.014950       -1.472500
# 50%               8.610200       -0.245000
# 75%              11.475750        1.462500
# max              16.428000        5.620000

# %%
inflation.to_csv("botswana-inflation-rate-cpi_processed.csv", index = False)

# %%
crash = pd.read_csv("tabula-2017-Crash-and-Claims-Report-.csv", on_bad_lines="skip")
crash.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0        NaN        NaN        NaN      Fatal     Claims       Reg.
# 1       Year    Crashes   Casualty        NaN        NaN        NaN
# 2        NaN        NaN        NaN      ities     Lodged    Vehicle
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4      1995-      79270      39386       2635       9547     137001
#
#   Unnamed: 6 Unnamed: 7  Casul Unnamed: 9 Unnamed: 10 Unnamed: 11
# 0        NaN   Crash/10    NaN     Fat/10     Fat/100    Claims/1
# 1   Est. Pop        NaN   /100        NaN         NaN         NaN
# 2        NaN     00 Veh    NaN    000 Veh     000 Pop     000 Veh
# 3        NaN        NaN  0 Veh        NaN         NaN         NaN
# 4    1642339        NaN    NaN        NaN         NaN         NaN

# %%
col = ["Year", "Crashes", "Casualty", "Fatalities", "ClaimsLodged", "Reg.Vehicle", "Est.Pop", "CrashPer1000Veh", "CasualtyPer1000Veh", "FatalityPer10000Veh", "FatalityPer100000Pop", "ClaimsPer1000Veh"]
crash[6:23]
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 6        2001      17125       7945        526       2510     152431
# 7        2002      18610       8014        520       2524     171398
# 8        2003      18329       7969        557       2649     187635
# 9        2004      18136       7840        532       2691     207205
# 10       2005      17522       7069        450       2611     227220
# 11       2006      17035       6952        429       2574     246185
# 12       2007      19487       7639        497       3082     270835
# 13       2008      20415       8160        455       2945     302988
# 14       2009      20000       7970        475       3217     333179
# 15       2010      18978       6430        397       2025     361308
# 16       2011      18001       6436        483       2356     390851
# 17       2012      17527       6035        404       2132     425911
# 18       2013      17062       6157        411       2078     462877
# ...

# %%
df1 = crash[6:23]
df1.columns = col
df1.tail()
# Out:
#     Year Crashes Casualty Fatalities ClaimsLodged Reg.Vehicle  Est.Pop  \
# 18  2013   17062     6157        411         2078      462877  2107484
# 19  2014   16641     6065        377         2109      502056  2147906
# 20  2015   17654     6303        411         2583      546484  2187477
# 21  2016   18373     6687        450         3019      596559  2226040
# 22  2017   17786     5033        444         2934      649519  2264993
#
#    CrashPer1000Veh CasualtyPer1000Veh FatalityPer10000Veh  \
# 18            36.9               13.3                 8.9
# 19            33.1               12.1                 7.5
# 20            32.3               11.5                 7.5
# 21            30.8               11.2                 7.5
# 22            27.4                7.7                 6.8
#
#    FatalityPer100000Pop ClaimsPer1000Veh
# 18                 19.5              4.5
# 19                 17.6              4.2
# 20                 18.8              4.7
# ...

# %%
df1.head()
# Out:
#     Year Crashes Casualty Fatalities ClaimsLodged Reg.Vehicle  Est.Pop  \
# 6   2001   17125     7945        526         2510      152431  1622129
# 7   2002   18610     8014        520         2524      171398  1649659
# 8   2003   18329     7969        557         2649      187635  1973184
# 9   2004   18136     7840        532         2691      207205  1692731
# 10  2005   17522     7069        450         2611      227220  1708327
#
#    CrashPer1000Veh CasualtyPer1000Veh FatalityPer10000Veh  \
# 6            112.3               52.1                34.5
# 7            108.6               46.8                30.3
# 8             97.7               42.5                29.7
# 9             87.5               37.8                25.7
# 10            77.1               31.1                19.8
#
#    FatalityPer100000Pop ClaimsPer1000Veh
# 6                  32.4             16.5
# 7                  31.5             14.7
# 8                  28.2             14.1
# ...

# %%
df1.to_csv("crashes_2001_2017_summary.csv", index = False)

# %%
crash[23:50]
# Out:
#                                            Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 23                                    Police District       2008       2009
# 24                                                NaN        NaN        NaN
# 25                                                NaN        NaN        NaN
# 26                                           Gaborone          2          2
# 27                                      Gaborone West          1          1
# 28                                             Serowe          3          3
# 29                                           Kutlwano          7          6
# 30                                              Kanye          6          7
# 31                                          Mahalapye          -          -
# 32                                         Molepolole          5          4
# 33                                        Francistown          4          5
# ...

# %%
crash.iloc[23:30, 10:]
# Out:
#    Unnamed: 10 Unnamed: 11
# 23        2017   Change in
# 24         NaN  Rank (2016
# 25         NaN   and 2017)
# 26           1          -1
# 27           2           1
# 28           3           0
# 29           4           0

# %%
col_names2 = ["Police District", "2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "ChangeRank2016.2017"]
df2 = crash[26:42]
df2.columns = col_names2
df2.head()
# Out:
#    Police District 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017  \
# 26        Gaborone    2    2    2    2    2    2    2    2    2    1
# 27   Gaborone West    1    1    1    1    1    1    1    1    1    2
# 28          Serowe    3    3    3    3    3    3    5    3    3    3
# 29        Kutlwano    7    6    6    5    5    6    3    4    4    4
# 30           Kanye    6    7    7    4    8    7    7    8    5    5
#
#    ChangeRank2016.2017
# 26                  -1
# 27                   1
# 28                   0
# 29                   0
# 30                   0

# %%
df2[["Police District", "ChangeRank2016.2017"]]
# Out:
#    Police District ChangeRank2016.2017
# 26        Gaborone                  -1
# 27   Gaborone West                   1
# 28          Serowe                   0
# 29        Kutlwano                   0
# 30           Kanye                   0
# 31       Mahalapye                  -1
# 32      Molepolole                  -2
# 33     Francistown                   2
# 34            Maun                   1
# 35         Mochudi                   0
# 36   Selebi-Phikwe                   0
# 37      Letlhakane                  -1
# 38         Lobatse                   1
# 39         Tsabong                  -1
# 40          Kasane                  -1
# 41          Ghanzi                   2

# %%
df2_set_ind = df2.set_index(["Police District", "ChangeRank2016.2017"])
df2_set_ind
# Out:
#                                     2008 2009 2010 2011 2012 2013 2014 2015  \
# Police District ChangeRank2016.2017
# Gaborone        -1                     2    2    2    2    2    2    2    2
# Gaborone West   1                      1    1    1    1    1    1    1    1
# Serowe          0                      3    3    3    3    3    3    5    3
# Kutlwano        0                      7    6    6    5    5    6    3    4
# Kanye           0                      6    7    7    4    8    7    7    8
# Mahalapye       -1                     -    -    -    -    -    4    8    9
# Molepolole      -2                     5    4    5    9    7    9    9    7
# Francistown     2                      4    5    4    7   10    8    6    5
# Maun            1                      8   10    8    6    4    5    4    6
# Mochudi         0                     10    9   10   10    9   11   11   11
# Selebi-Phikwe   0                      9    8    9    8    6   12   10   10
# ...

# %%
year = list(df2_set_ind.iloc[:,0:].columns)
df2_long = pd.melt(df2_set_ind, value_vars=year, var_name="Year", value_name="Rank_of_Crash", ignore_index=False)
df2_long
# Out:
#                                      Year Rank
# Police District ChangeRank2016.2017
# Gaborone        -1                   2008    2
# Gaborone West   1                    2008    1
# Serowe          0                    2008    3
# Kutlwano        0                    2008    7
# Kanye           0                    2008    6
# ...                                   ...  ...
# Letlhakane      -1                   2017   12
# Lobatse         1                    2017   13
# Tsabong         -1                   2017   14
# Kasane          -1                   2017   15
# Ghanzi          2                    2017   16
#
# [160 rows x 2 columns]

# %%
df2_long.reset_index(drop=False, inplace=True)
df2_long
# Out:
#     Police District ChangeRank2016.2017  Year Rank
# 0          Gaborone                  -1  2008    2
# 1     Gaborone West                   1  2008    1
# 2            Serowe                   0  2008    3
# 3          Kutlwano                   0  2008    7
# 4             Kanye                   0  2008    6
# ..              ...                 ...   ...  ...
# 155      Letlhakane                  -1  2017   12
# 156         Lobatse                   1  2017   13
# 157         Tsabong                  -1  2017   14
# 158          Kasane                  -1  2017   15
# 159          Ghanzi                   2  2017   16
#
# [160 rows x 4 columns]

# %%
crash[48:68]
# Out:
#                                            Unnamed: 0     Unnamed: 1  \
# 48  major highways. The trends indicate that most ...            NaN
# 49                                    Police District           2008
# 50                                      Gaborone West             38
# 51                                             Serowe             51
# 52                                         Molepolole             31
# 53                                           Gaborone             26
# 54                                              Kanye             32
# 55                                           Kutlwano             30
# 56                                            Mochudi             20
# 57                                               Maun             19
# 58                                      Selebi-Phikwe             26
# 59                                        Francistown             19
# 60                                         Letlhakane             14
# ...

# %%
col_names3 = ["Police District", "2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017"]
df3 = crash.iloc[50:66,0:11]
df3.columns = col_names3
df3
# Out:
#    Police District 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
# 50   Gaborone West   38   49   45   59   47   50   56   52   46   54
# 51          Serowe   51   74   49   57   44   39   31   27   34   32
# 52      Molepolole   31   19   27   31   42   27   29   20   27   35
# 53        Gaborone   26   34   21   32   28   22   11   36   29   26
# 54           Kanye   32   31   22   25   16   26   27   29   26   23
# 55        Kutlwano   30   31   18   22   21   15   18   22   26   20
# 56         Mochudi   20   25   31   31   18   15   13   14   28   23
# 57            Maun   19   17   19   17   16   17   18   15   26   21
# 58   Selebi-Phikwe   26   22   18   25   22   15   10   16   11    7
# 59     Francistown   19    9   11   11   11    8   15   22   21   27
# 60      Letlhakane   14   22   23   16   14   19   12   12    5   16
# 61         Lobatse   18   16   12   16   18   18    4   11   16   18
# 62       Mahalapye  NaN  NaN  NaN  NaN  NaN   23   21   27   26   33
# ...

# %%
df3_set_ind = df3.set_index("Police District")
df3_set_ind
# Out:
#                 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
# Police District
# Gaborone West     38   49   45   59   47   50   56   52   46   54
# Serowe            51   74   49   57   44   39   31   27   34   32
# Molepolole        31   19   27   31   42   27   29   20   27   35
# Gaborone          26   34   21   32   28   22   11   36   29   26
# Kanye             32   31   22   25   16   26   27   29   26   23
# Kutlwano          30   31   18   22   21   15   18   22   26   20
# Mochudi           20   25   31   31   18   15   13   14   28   23
# Maun              19   17   19   17   16   17   18   15   26   21
# Selebi-Phikwe     26   22   18   25   22   15   10   16   11    7
# Francistown       19    9   11   11   11    8   15   22   21   27
# Letlhakane        14   22   23   16   14   19   12   12    5   16
# Lobatse           18   16   12   16   18   18    4   11   16   18
# Mahalapye        NaN  NaN  NaN  NaN  NaN   23   21   27   26   33
# ...

# %%
df3_long = pd.melt(df3_set_ind, value_vars=year, var_name="Year", value_name="Fatal_Crashes", ignore_index=False)
df3_long
# Out:
#                  Year Fatal_Crashes
# Police District
# Gaborone West    2008            38
# Serowe           2008            51
# Molepolole       2008            31
# Gaborone         2008            26
# Kanye            2008            32
# ...               ...           ...
# Lobatse          2017            18
# Mahalapye        2017            33
# Ghanzi           2017            14
# Tsabong          2017             7
# Kasane           2017            10
#
# [160 rows x 2 columns]

# %%
df3_long.reset_index(drop=False, inplace=True)
df3_long
# Out:
#     Police District  Year Fatal_Crashes
# 0     Gaborone West  2008            38
# 1            Serowe  2008            51
# 2        Molepolole  2008            31
# 3          Gaborone  2008            26
# 4             Kanye  2008            32
# ..              ...   ...           ...
# 155         Lobatse  2017            18
# 156       Mahalapye  2017            33
# 157          Ghanzi  2017            14
# 158         Tsabong  2017             7
# 159          Kasane  2017            10
#
# [160 rows x 3 columns]

# %%
df2_df3 = df2_long.merge(df3_long, how='outer', on=["Police District", "Year"])
df2_df3
# Out:
#     Police District ChangeRank2016.2017  Year Rank Fatal_Crashes
# 0          Gaborone                  -1  2008    2            26
# 1     Gaborone West                   1  2008    1            38
# 2            Serowe                   0  2008    3            51
# 3          Kutlwano                   0  2008    7            30
# 4             Kanye                   0  2008    6            32
# ..              ...                 ...   ...  ...           ...
# 155      Letlhakane                  -1  2017   12            16
# 156         Lobatse                   1  2017   13            18
# 157         Tsabong                  -1  2017   14             7
# 158          Kasane                  -1  2017   15            10
# 159          Ghanzi                   2  2017   16            14
#
# [160 rows x 5 columns]

# %%
df2_df3.to_csv("crashes_2008_2017_by_rank.csv", index = False)

# %%
crash[65:90]
# Out:
#          Unnamed: 0      Unnamed: 1  Unnamed: 2              Unnamed: 3  \
# 65           Kasane              12           5                      14
# 66            Total             355         372                     327
# 67             Year   Fatal Crashes  Fatalities  Fatalities/Fatal Crash
# 68             2008             355         455                   1.282
# 69             2009             372         475                   1.277
# 70             2010             327         397                   1.214
# 71             2011             369         483                   1.309
# 72             2012             328         404                   1.232
# 73             2013             321         411                   1.280
# 74             2014             288         377                   1.309
# 75             2015             329         411                   1.249
# 76             2016             348         450                   1.293
# ...

# %%
df4 = crash.iloc[67:78, :4]
df4
# Out:
#    Unnamed: 0     Unnamed: 1  Unnamed: 2              Unnamed: 3
# 67       Year  Fatal Crashes  Fatalities  Fatalities/Fatal Crash
# 68       2008            355         455                   1.282
# 69       2009            372         475                   1.277
# 70       2010            327         397                   1.214
# 71       2011            369         483                   1.309
# 72       2012            328         404                   1.232
# 73       2013            321         411                   1.280
# 74       2014            288         377                   1.309
# 75       2015            329         411                   1.249
# 76       2016            348         450                   1.293
# 77       2017            366         444                   1.213

# %%
df4.columns = df4.iloc[0]
df4.drop(df4.index[0], inplace = True)

# %%
df4
# Out:
# 67  Year Fatal Crashes Fatalities Fatalities/Fatal Crash
# 68  2008           355        455                  1.282
# 69  2009           372        475                  1.277
# 70  2010           327        397                  1.214
# 71  2011           369        483                  1.309
# 72  2012           328        404                  1.232
# 73  2013           321        411                  1.280
# 74  2014           288        377                  1.309
# 75  2015           329        411                  1.249
# 76  2016           348        450                  1.293
# 77  2017           366        444                  1.213

# %%
crash[78:115]
# Out:
#           Unnamed: 0      Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 78   Police District             NaN        NaN  Fatalities        NaN
# 79               NaN  Police Station       2014   2015 2016       2017
# 80     Gaborone West          G-West         22       20 14         15
# 81               NaN          Naledi          5         5 3          1
# 82               NaN        Ramotswa         11        10 8         14
# 83               NaN     SSK Airport          5         2 4          3
# 84               NaN    Mogoditshane         25       20 20         32
# 85         Sub total             NaN         68       57 49         65
# 86         Mahalapye       Mahalapye         11       17 23         21
# 87               NaN        Shoshong          2         2 1          6
# 88               NaN       Machaneng          2         3 2          1
# 89               NaN     Martindrift          1        19 3          5
# ...

# %%
df5_fatal = crash.iloc[80:110, 0:5]
df5_serious_inj = crash.iloc[80:110, [0,1,5,6,7]]
df5_minor_inj = crash.iloc[80:110, [0,1,8,9,10]]
df5_fatal.head()
# Out:
#        Unnamed: 0    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4
# 80  Gaborone West        G-West         22      20 14         15
# 81            NaN        Naledi          5        5 3          1
# 82            NaN      Ramotswa         11       10 8         14
# 83            NaN   SSK Airport          5        2 4          3
# 84            NaN  Mogoditshane         25      20 20         32

# %%
col5 = ["Police District", "Police Station", "2014", "2015_2016", "2017"]
df5_fatal.columns = col5
df5_fatal.head()
# Out:
#    Police District Police Station 2014 2015_2016 2017
# 80   Gaborone West         G-West   22     20 14   15
# 81             NaN         Naledi    5       5 3    1
# 82             NaN       Ramotswa   11      10 8   14
# 83             NaN    SSK Airport    5       2 4    3
# 84             NaN   Mogoditshane   25     20 20   32

# %%
df5_fatal[["2015", "2016"]] = df5_fatal["2015_2016"].str.split(" ", expand = True)

# %%
df5_fatal.drop(columns = ["2015_2016"], axis = 1, inplace = True)
df5_fatal
# Out:
#     Police District Police Station 2014 2017 2015 2016
# 80    Gaborone West         G-West   22   15   20   14
# 81              NaN         Naledi    5    1    5    3
# 82              NaN       Ramotswa   11   14   10    8
# 83              NaN    SSK Airport    5    3    2    4
# 84              NaN   Mogoditshane   25   32   20   20
# 85        Sub total            NaN   68   65   57   49
# 86        Mahalapye      Mahalapye   11   21   17   23
# 87              NaN       Shoshong    2    6    2    1
# 88              NaN      Machaneng    2    1    3    2
# 89              NaN    Martindrift    1    5   19    3
# 90              NaN         Dibete   16   10   13   13
# 91        Sub total            NaN   32   43   54   42
# 92       Molepolole     Letlhakeng    1    2    1    2
# 93              NaN     Molepolole   12   16   10   15
# 94              NaN        Thamaga   15   15    7    9
# 95              NaN    Takatokwane    3    2    8    2
# ...

# %%
index_sub = df5_fatal[df5_fatal["Police District"] == "Sub total"].index
df5_fatal.drop(index_sub , inplace=True)
df5_fatal
# Out:
#     Police District Police Station 2014 2017 2015 2016
# 80    Gaborone West         G-West   22   15   20   14
# 81              NaN         Naledi    5    1    5    3
# 82              NaN       Ramotswa   11   14   10    8
# 83              NaN    SSK Airport    5    3    2    4
# 84              NaN   Mogoditshane   25   32   20   20
# 86        Mahalapye      Mahalapye   11   21   17   23
# 87              NaN       Shoshong    2    6    2    1
# 88              NaN      Machaneng    2    1    3    2
# 89              NaN    Martindrift    1    5   19    3
# 90              NaN         Dibete   16   10   13   13
# 92       Molepolole     Letlhakeng    1    2    1    2
# 93              NaN     Molepolole   12   16   10   15
# 94              NaN        Thamaga   15   15    7    9
# 95              NaN    Takatokwane    3    2    8    2
# 96              NaN          Sojwe    0    7    1    2
# 98           Serowe        Palapye   29   20   11   25
# ...

# %%
df5_fatal_set_ind = df5_fatal.set_index(["Police District", "Police Station"])
df5_fatal_set_ind
# Out:
#                                2014 2017 2015 2016
# Police District Police Station
# Gaborone West   G-West           22   15   20   14
# NaN             Naledi            5    1    5    3
#                 Ramotswa         11   14   10    8
#                 SSK Airport       5    3    2    4
#                 Mogoditshane     25   32   20   20
# Mahalapye       Mahalapye        11   21   17   23
# NaN             Shoshong          2    6    2    1
#                 Machaneng         2    1    3    2
#                 Martindrift       1    5   19    3
#                 Dibete           16   10   13   13
# Molepolole      Letlhakeng        1    2    1    2
# NaN             Molepolole       12   16   10   15
#                 Thamaga          15   15    7    9
#                 Takatokwane       3    2    8    2
#                 Sojwe             0    7    1    2
# Serowe          Palapye          29   20   11   25
# NaN             Serowe           16   11   13   17
# ...

# %%
year5 = list(df5_fatal_set_ind.iloc[:,0:].columns)
df5_fatal_long = pd.melt(df5_fatal_set_ind, value_vars=year5, var_name="Year", value_name="Fatalities", ignore_index=False)
df5_fatal_long.tail()
# Out:
#                                 Year Fatalities
# Police District Police Station
# NaN             Tatitown        2016         21
#                 Matsiloje       2016          1
#                 Tonota          2016          7
#                 Gerald          2016          0
#                 Dukwi           2016          2

# %%
df5_fatal_long.reset_index(drop=False, inplace=True)
df5_fatal_long
# Out:
#    Police District Police Station  Year Fatalities
# 0    Gaborone West         G-West  2014         22
# 1              NaN         Naledi  2014          5
# 2              NaN       Ramotswa  2014         11
# 3              NaN    SSK Airport  2014          5
# 4              NaN   Mogoditshane  2014         25
# ..             ...            ...   ...        ...
# 95             NaN       Tatitown  2016         21
# 96             NaN      Matsiloje  2016          1
# 97             NaN         Tonota  2016          7
# 98             NaN         Gerald  2016          0
# 99             NaN          Dukwi  2016          2
#
# [100 rows x 4 columns]

# %%
df5_serious_inj.columns = col5
df5_minor_inj.columns = col5
df5_serious_inj[["2015", "2016"]] = df5_serious_inj["2015_2016"].str.split(" ", expand = True)
df5_minor_inj[["2015", "2016"]] = df5_minor_inj["2015_2016"].str.split(" ", expand = True)
df5_serious_inj.drop(columns = ["2015_2016"], axis = 1, inplace = True)
df5_minor_inj.drop(columns = ["2015_2016"], axis = 1, inplace = True)
ind_ser = df5_serious_inj[df5_serious_inj["Police District"] == "Sub total"].index
ind_minor = df5_minor_inj[df5_minor_inj["Police District"] == "Sub total"].index
df5_serious_inj.drop(ind_ser , inplace=True)
df5_minor_inj.drop(ind_minor , inplace=True)

# %%
df5_serious_inj
# Out:
#     Police District Police Station 2014 2017 2015 2016
# 80    Gaborone West         G-West   31   29   43   34
# 81              NaN         Naledi   15   16   10   11
# 82              NaN       Ramotswa   15   18   29   30
# 83              NaN    SSK Airport   25   15   13   25
# 84              NaN   Mogoditshane   77   88   79   87
# 86        Mahalapye      Mahalapye   43   46   59   49
# 87              NaN       Shoshong    1    5    5    2
# 88              NaN      Machaneng   12    7   11   10
# 89              NaN    Martindrift    0   11   17    2
# 90              NaN         Dibete   50   21   50   24
# 92       Molepolole     Letlhakeng   15   13    7   12
# 93              NaN     Molepolole   27   35   39   30
# 94              NaN        Thamaga   34   23   24   35
# 95              NaN    Takatokwane    2    3  106    5
# 96              NaN          Sojwe    4   10    6    1
# 98           Serowe        Palapye   69   36   23   43
# ...

# %%
df5_minor_inj
# Out:
#     Police District Police Station 2014 2017 2015 2016
# 80    Gaborone West         G-West  211  249  247  281
# 81              NaN         Naledi   52   69   89  119
# 82              NaN       Ramotswa   63   72   94   81
# 83              NaN    SSK Airport   81   56   58   74
# 84              NaN   Mogoditshane  385  440  394  457
# 86        Mahalapye      Mahalapye  182  123  154  208
# 87              NaN       Shoshong   13   10   14   19
# 88              NaN      Machaneng   26   32   33   23
# 89              NaN    Martindrift  123   16   24   22
# 90              NaN         Dibete   59   55   42   32
# 92       Molepolole     Letlhakeng   30   40   34   35
# 93              NaN     Molepolole  151  123  151  119
# 94              NaN        Thamaga  124  117   85   80
# 95              NaN    Takatokwane   13    9   20    3
# 96              NaN          Sojwe   12   17   15   15
# 98           Serowe        Palapye  205  161  128  144
# ...

# %%
df5_serious_set_ind = df5_serious_inj.set_index(["Police District", "Police Station"])
df5_minor_set_ind = df5_minor_inj.set_index(["Police District", "Police Station"])

# %%
df5_minor_set_ind
# Out:
#                                2014 2017 2015 2016
# Police District Police Station
# Gaborone West   G-West          211  249  247  281
# NaN             Naledi           52   69   89  119
#                 Ramotswa         63   72   94   81
#                 SSK Airport      81   56   58   74
#                 Mogoditshane    385  440  394  457
# Mahalapye       Mahalapye       182  123  154  208
# NaN             Shoshong         13   10   14   19
#                 Machaneng        26   32   33   23
#                 Martindrift     123   16   24   22
#                 Dibete           59   55   42   32
# Molepolole      Letlhakeng       30   40   34   35
# NaN             Molepolole      151  123  151  119
#                 Thamaga         124  117   85   80
#                 Takatokwane      13    9   20    3
#                 Sojwe            12   17   15   15
# Serowe          Palapye         205  161  128  144
# NaN             Serowe          189  202  142  209
# ...

# %%
year5_2 = list(df5_serious_set_ind.iloc[:,0:].columns)
year5_3 = list(df5_minor_set_ind.iloc[:,0:].columns)
df5_serious_inj_long = pd.melt(df5_serious_set_ind, value_vars=year5_2, var_name="Year", value_name="Serious Injury", ignore_index=False)
df5_minor_inj_long = pd.melt(df5_minor_set_ind, value_vars=year5_3, var_name="Year", value_name="Minor Injury", ignore_index=False)

# %%
df5_minor_inj_long
# Out:
#                                 Year Minor Injury
# Police District Police Station
# Gaborone West   G-West          2014          211
# NaN             Naledi          2014           52
#                 Ramotswa        2014           63
#                 SSK Airport     2014           81
#                 Mogoditshane    2014          385
# ...                              ...          ...
#                 Tatitown        2016           59
#                 Matsiloje       2016            7
#                 Tonota          2016           84
#                 Gerald          2016           23
#                 Dukwi           2016           16
#
# [100 rows x 2 columns]

# %%
df5_serious_inj_long.reset_index(drop=False, inplace=True)
df5_minor_inj_long.reset_index(drop=False, inplace=True)

# %%
df5_minor_inj_long
# Out:
#    Police District Police Station  Year Minor Injury
# 0    Gaborone West         G-West  2014          211
# 1              NaN         Naledi  2014           52
# 2              NaN       Ramotswa  2014           63
# 3              NaN    SSK Airport  2014           81
# 4              NaN   Mogoditshane  2014          385
# ..             ...            ...   ...          ...
# 95             NaN       Tatitown  2016           59
# 96             NaN      Matsiloje  2016            7
# 97             NaN         Tonota  2016           84
# 98             NaN         Gerald  2016           23
# 99             NaN          Dukwi  2016           16
#
# [100 rows x 4 columns]

# %%
df5_part = df5_fatal_long.merge(df5_serious_inj_long, how='inner', on=["Police District", "Police Station", "Year"])

# %%
df5 = df5_part.merge(df5_minor_inj_long, how='inner', on=["Police District", "Police Station", "Year"])

# %%
df5
# Out:
#    Police District Police Station  Year Fatalities Serious Injury Minor Injury
# 0    Gaborone West         G-West  2014         22             31          211
# 1              NaN         Naledi  2014          5             15           52
# 2              NaN       Ramotswa  2014         11             15           63
# 3              NaN    SSK Airport  2014          5             25           81
# 4              NaN   Mogoditshane  2014         25             77          385
# ..             ...            ...   ...        ...            ...          ...
# 95             NaN       Tatitown  2016         21             35           59
# 96             NaN      Matsiloje  2016          1              2            7
# 97             NaN         Tonota  2016          7             35           84
# 98             NaN         Gerald  2016          0              8           23
# 99             NaN          Dukwi  2016          2             17           16
#
# [100 rows x 6 columns]

# %%
df5['Police District'].fillna(method='pad',inplace=True)
df5
# Out:
#    Police District Police Station  Year Fatalities Serious Injury Minor Injury
# 0    Gaborone West         G-West  2014         22             31          211
# 1    Gaborone West         Naledi  2014          5             15           52
# 2    Gaborone West       Ramotswa  2014         11             15           63
# 3    Gaborone West    SSK Airport  2014          5             25           81
# 4    Gaborone West   Mogoditshane  2014         25             77          385
# ..             ...            ...   ...        ...            ...          ...
# 95        Kutlwano       Tatitown  2016         21             35           59
# 96        Kutlwano      Matsiloje  2016          1              2            7
# 97        Kutlwano         Tonota  2016          7             35           84
# 98        Kutlwano         Gerald  2016          0              8           23
# 99        Kutlwano          Dukwi  2016          2             17           16
#
# [100 rows x 6 columns]

# %%
df5.to_csv("crashes_2014_2017_by_police_districts.csv", index = False)

# %%
crash[188:230]
# Out:
#           Unnamed: 0      Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 188  Police District             NaN  Fatalities        NaN        NaN
# 189              NaN  Police Station   2014 2015       2016       2017
# 190          Lobatse         Lobatse         2 4          7          5
# 191              NaN     Ramatlabama         1 0          2          2
# 192              NaN        Woodhall         2 6          1         10
# 193              NaN        Goodhope         0 2          6          4
# 194        Sub total             NaN        5 12         16         21
# 195             Maun            Maun       11 12         19         12
# 196              NaN         Sehitwa         3 0          3          3
# 197              NaN         Seronga         0 0          2          2
# 198              NaN         Shakawe         2 3          7          1
# 199              NaN          Gumare         1 1          0          3
# ...

# %%
df6_fatal = crash.iloc[190:225, 0:5]
df6_serious = crash.iloc[190:225, [0,1,5,6,7]]
df6_minor = crash.iloc[190:225, [0,1,8,9,10]]
df6_serious.head()
# Out:
#     Unnamed: 0   Unnamed: 1 Unnamed: 5 Unnamed: 6 Unnamed: 7
# 190    Lobatse      Lobatse      24 12         19         13
# 191        NaN  Ramatlabama        2 7          4          5
# 192        NaN     Woodhall      13 29         10         23
# 193        NaN     Goodhope        4 7         13         15
# 194  Sub total          NaN      43 55         46         56

# %%
col6 = ["Police District", "Police Station", "2014_2015", "2016", "2017"]
df6_fatal.columns = col6
df6_serious.columns = col6
df6_minor.columns = col6
df6_minor.head()
# Out:
#     Police District Police Station 2014_2015 2016 2017
# 190         Lobatse        Lobatse     39 47   29   40
# 191             NaN    Ramatlabama     13 34   13   18
# 192             NaN       Woodhall     34 53   35   44
# 193             NaN       Goodhope     20 35   30   30
# 194       Sub total            NaN   106 169  107  132

# %%
df6_fatal
# Out:
#     Police District Police Station 2014_2015 2016 2017
# 190         Lobatse        Lobatse       2 4    7    5
# 191             NaN    Ramatlabama       1 0    2    2
# 192             NaN       Woodhall       2 6    1   10
# 193             NaN       Goodhope       0 2    6    4
# 194       Sub total            NaN      5 12   16   21
# 195            Maun           Maun     11 12   19   12
# 196             NaN        Sehitwa       3 0    3    3
# 197             NaN        Seronga       0 0    2    2
# 198             NaN        Shakawe       2 3    7    1
# 199             NaN         Gumare       1 1    0    3
# 200             NaN          Gweta       6 3    1    0
# 201       Sub total            NaN     23 19   32   21
# 202          Ghanzi         Ghanzi      8 10   14    9
# 203             NaN    Kalkfontein       1 1    3    6
# 204             NaN    Charlsehill       2 6    1    1
# 205             NaN         Nojane       0 0    0    0
# ...

# %%
df6_fatal[["2014", "2015"]] = df6_fatal["2014_2015"].str.split(" ", expand = True)

# %%
df6_serious[["2014", "2015"]] = df6_serious["2014_2015"].str.split(" ", expand = True)
df6_minor[["2014", "2015"]] = df6_minor["2014_2015"].str.split(" ", expand = True)

# %%
df6_fatal.drop(columns = ["2014_2015"], axis = 1, inplace = True)
df6_fatal
# Out:
#     Police District Police Station 2016 2017 2014 2015
# 190         Lobatse        Lobatse    7    5    2    4
# 191             NaN    Ramatlabama    2    2    1    0
# 192             NaN       Woodhall    1   10    2    6
# 193             NaN       Goodhope    6    4    0    2
# 194       Sub total            NaN   16   21    5   12
# 195            Maun           Maun   19   12   11   12
# 196             NaN        Sehitwa    3    3    3    0
# 197             NaN        Seronga    2    2    0    0
# 198             NaN        Shakawe    7    1    2    3
# 199             NaN         Gumare    0    3    1    1
# 200             NaN          Gweta    1    0    6    3
# 201       Sub total            NaN   32   21   23   19
# 202          Ghanzi         Ghanzi   14    9    8   10
# 203             NaN    Kalkfontein    3    6    1    1
# 204             NaN    Charlsehill    1    1    2    6
# 205             NaN         Nojane    0    0    0    0
# ...

# %%
df6_serious.drop(columns = ["2014_2015"], axis = 1, inplace = True)
df6_minor.drop(columns = ["2014_2015"], axis = 1, inplace = True)
df6_serious
# Out:
#     Police District Police Station 2016 2017 2014 2015
# 190         Lobatse        Lobatse   19   13   24   12
# 191             NaN    Ramatlabama    4    5    2    7
# 192             NaN       Woodhall   10   23   13   29
# 193             NaN       Goodhope   13   15    4    7
# 194       Sub total            NaN   46   56   43   55
# 195            Maun           Maun   38   40   59   62
# 196             NaN        Sehitwa   12   13   12    8
# 197             NaN        Seronga    4    3    4    4
# 198             NaN        Shakawe   18    8    7    6
# 199             NaN         Gumare   12   12    9    6
# 200             NaN          Gweta    5    1   14   13
# 201       Sub total            NaN   89   77  105   99
# 202          Ghanzi         Ghanzi   19   15   30   28
# 203             NaN    Kalkfontein    2    8    2    6
# 204             NaN    Charlsehill    9    4    9    7
# 205             NaN         Nojane    2    0    1    1
# ...

# %%
index6_fatal = df6_fatal[df6_fatal["Police District"] == "Sub total"].index
df6_fatal.drop(index6_fatal , inplace=True)
df6_fatal
# Out:
#     Police District Police Station 2016 2017 2014 2015
# 190         Lobatse        Lobatse    7    5    2    4
# 191             NaN    Ramatlabama    2    2    1    0
# 192             NaN       Woodhall    1   10    2    6
# 193             NaN       Goodhope    6    4    0    2
# 195            Maun           Maun   19   12   11   12
# 196             NaN        Sehitwa    3    3    3    0
# 197             NaN        Seronga    2    2    0    0
# 198             NaN        Shakawe    7    1    2    3
# 199             NaN         Gumare    0    3    1    1
# 200             NaN          Gweta    1    0    6    3
# 202          Ghanzi         Ghanzi   14    9    8   10
# 203             NaN    Kalkfontein    3    6    1    1
# 204             NaN    Charlsehill    1    1    2    6
# 205             NaN         Nojane    0    0    0    0
# 207          Kasane         Kasane    0    2    3    1
# 208             NaN       Kachikau    0    1    2    0
# ...

# %%
index6_serious = df6_serious[df6_serious["Police District"] == "Sub total"].index
df6_serious.drop(index6_serious , inplace=True)
df6_serious
# Out:
#     Police District Police Station 2016 2017 2014 2015
# 190         Lobatse        Lobatse   19   13   24   12
# 191             NaN    Ramatlabama    4    5    2    7
# 192             NaN       Woodhall   10   23   13   29
# 193             NaN       Goodhope   13   15    4    7
# 195            Maun           Maun   38   40   59   62
# 196             NaN        Sehitwa   12   13   12    8
# 197             NaN        Seronga    4    3    4    4
# 198             NaN        Shakawe   18    8    7    6
# 199             NaN         Gumare   12   12    9    6
# 200             NaN          Gweta    5    1   14   13
# 202          Ghanzi         Ghanzi   19   15   30   28
# 203             NaN    Kalkfontein    2    8    2    6
# 204             NaN    Charlsehill    9    4    9    7
# 205             NaN         Nojane    2    0    1    1
# 207          Kasane         Kasane   11   10   16   15
# 208             NaN       Kachikau    0    2    5    1
# ...

# %%
index6_minor = df6_minor[df6_minor["Police District"] == "Sub total"].index
df6_minor.drop(index6_minor , inplace=True)
df6_minor
# Out:
#     Police District Police Station 2016 2017 2014 2015
# 190         Lobatse        Lobatse   29   40   39   47
# 191             NaN    Ramatlabama   13   18   13   34
# 192             NaN       Woodhall   35   44   34   53
# 193             NaN       Goodhope   30   30   20   35
# 195            Maun           Maun  180  188  188  202
# 196             NaN        Sehitwa   47   16   84   31
# 197             NaN        Seronga   15    7   10    9
# 198             NaN        Shakawe   19    9   17   21
# 199             NaN         Gumare   34   37   27   24
# 200             NaN          Gweta   12   18   22   28
# 202          Ghanzi         Ghanzi   35   40   45   59
# 203             NaN    Kalkfontein   31   25    9    8
# 204             NaN    Charlsehill   25   22   11   21
# 205             NaN         Nojane    9    7   14   18
# 207          Kasane         Kasane   34   15   20   35
# 208             NaN       Kachikau    7    6   10    6
# ...

# %%
df6_fatal_set_ind = df6_fatal.set_index(["Police District", "Police Station"])
df6_serious_set_ind = df6_serious.set_index(["Police District", "Police Station"])
df6_minor_set_ind = df6_minor.set_index(["Police District", "Police Station"])
df6_serious_set_ind
# Out:
#                                2016 2017 2014 2015
# Police District Police Station
# Lobatse         Lobatse          19   13   24   12
# NaN             Ramatlabama       4    5    2    7
#                 Woodhall         10   23   13   29
#                 Goodhope         13   15    4    7
# Maun            Maun             38   40   59   62
# NaN             Sehitwa          12   13   12    8
#                 Seronga           4    3    4    4
#                 Shakawe          18    8    7    6
#                 Gumare           12   12    9    6
#                 Gweta             5    1   14   13
# Ghanzi          Ghanzi           19   15   30   28
# NaN             Kalkfontein       2    8    2    6
#                 Charlsehill       9    4    9    7
#                 Nojane            2    0    1    1
# Kasane          Kasane           11   10   16   15
# NaN             Kachikau          0    2    5    1
#                 Kazungula         3   15  NaN  NaN
# ...

# %%
year6 = list(df6_fatal_set_ind.iloc[:,0:].columns)
df6_fatal_long = pd.melt(df6_fatal_set_ind, value_vars=year6, var_name="Year", value_name="Fatalities", ignore_index=False)
df6_fatal_long
# Out:
#                                 Year Fatalities
# Police District Police Station
# Lobatse         Lobatse         2016          7
# NaN             Ramatlabama     2016          2
#                 Woodhall        2016          1
#                 Goodhope        2016          6
# Maun            Maun            2016         19
# ...                              ...        ...
# Selibe Phikwe   Bainsdrift      2015          2
# NaN             Bobonong        2015          2
#                 Botshabelo      2015          9
#                 Selebi-Phikwe   2015          5
#                 Semolale        2015          0
#
# [116 rows x 2 columns]

# %%
year6_2 = list(df6_serious_set_ind.iloc[:,0:].columns)
year6_3 = list(df6_minor_set_ind.iloc[:,0:].columns)
df6_serious_long = pd.melt(df6_serious_set_ind, value_vars=year6_2, var_name="Year", value_name="Serious Injury", ignore_index=False)
df6_minor_long = pd.melt(df6_minor_set_ind, value_vars=year6_3, var_name="Year", value_name="Minor Injury", ignore_index=False)
df6_minor_long
# Out:
#                                 Year Minor Injury
# Police District Police Station
# Lobatse         Lobatse         2016           29
# NaN             Ramatlabama     2016           13
#                 Woodhall        2016           35
#                 Goodhope        2016           30
# Maun            Maun            2016          180
# ...                              ...          ...
# Selibe Phikwe   Bainsdrift      2015            7
# NaN             Bobonong        2015           35
#                 Botshabelo      2015           41
#                 Selebi-Phikwe   2015           87
#                 Semolale        2015            0
#
# [116 rows x 2 columns]

# %%
df6_fatal_long.reset_index(drop=False, inplace=True)
df6_serious_long.reset_index(drop=False, inplace=True)
df6_minor_long.reset_index(drop=False, inplace=True)
df6_minor_long
# Out:
#     Police District Police Station  Year Minor Injury
# 0           Lobatse        Lobatse  2016           29
# 1               NaN    Ramatlabama  2016           13
# 2               NaN       Woodhall  2016           35
# 3               NaN       Goodhope  2016           30
# 4              Maun           Maun  2016          180
# ..              ...            ...   ...          ...
# 111   Selibe Phikwe     Bainsdrift  2015            7
# 112             NaN       Bobonong  2015           35
# 113             NaN     Botshabelo  2015           41
# 114             NaN  Selebi-Phikwe  2015           87
# 115             NaN       Semolale  2015            0
#
# [116 rows x 4 columns]

# %%
df6 = df6_fatal_long.merge(df6_serious_long, how='inner', on=["Police District", "Police Station", "Year"])
df6 = df6.merge(df6_minor_long, how='inner', on=["Police District", "Police Station", "Year"])
df6
# Out:
#     Police District Police Station  Year Fatalities Serious Injury  \
# 0           Lobatse        Lobatse  2016          7             19
# 1               NaN    Ramatlabama  2016          2              4
# 2               NaN       Woodhall  2016          1             10
# 3               NaN       Goodhope  2016          6             13
# 4              Maun           Maun  2016         19             38
# ..              ...            ...   ...        ...            ...
# 111   Selibe Phikwe     Bainsdrift  2015          2              4
# 112             NaN       Bobonong  2015          2             25
# 113             NaN     Botshabelo  2015          9             17
# 114             NaN  Selebi-Phikwe  2015          5             18
# 115             NaN       Semolale  2015          0              0
#
#     Minor Injury
# 0             29
# 1             13
# 2             35
# 3             30
# 4            180
# ..           ...
# 111            7
# ...

# %%
df6['Police District'].fillna(method='pad',inplace=True)
df6
# Out:
#     Police District Police Station  Year Fatalities Serious Injury  \
# 0           Lobatse        Lobatse  2016          7             19
# 1           Lobatse    Ramatlabama  2016          2              4
# 2           Lobatse       Woodhall  2016          1             10
# 3           Lobatse       Goodhope  2016          6             13
# 4              Maun           Maun  2016         19             38
# ..              ...            ...   ...        ...            ...
# 111   Selibe Phikwe     Bainsdrift  2015          2              4
# 112   Selibe Phikwe       Bobonong  2015          2             25
# 113   Selibe Phikwe     Botshabelo  2015          9             17
# 114   Selibe Phikwe  Selebi-Phikwe  2015          5             18
# 115   Selibe Phikwe       Semolale  2015          0              0
#
#     Minor Injury
# 0             29
# 1             13
# 2             35
# 3             30
# 4            180
# ..           ...
# 111            7
# ...

# %%
df5_df6 = pd.concat([df5, df6], ignore_index=True, sort=False)
df5_df6
# Out:
#     Police District Police Station  Year Fatalities Serious Injury  \
# 0     Gaborone West         G-West  2014         22             31
# 1     Gaborone West         Naledi  2014          5             15
# 2     Gaborone West       Ramotswa  2014         11             15
# 3     Gaborone West    SSK Airport  2014          5             25
# 4     Gaborone West   Mogoditshane  2014         25             77
# ..              ...            ...   ...        ...            ...
# 211   Selibe Phikwe     Bainsdrift  2015          2              4
# 212   Selibe Phikwe       Bobonong  2015          2             25
# 213   Selibe Phikwe     Botshabelo  2015          9             17
# 214   Selibe Phikwe  Selebi-Phikwe  2015          5             18
# 215   Selibe Phikwe       Semolale  2015          0              0
#
#     Minor Injury
# 0            211
# 1             52
# 2             63
# 3             81
# 4            385
# ..           ...
# 211            7
# ...

# %%
df5_df6.to_csv('crashes_2014_2017_by_police_districts.csv', index = False)

# %%
crash[261:320]
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 261  Road Year        NaN      Rear-       Side    Head-On         Hit
# 262        NaN        NaN        end        NaN        NaN  Pedestrian
# 263    A1 2009        NaN        256        211         36          38
# 264       2010        NaN        404        282         31          67
# 265       2011        NaN        332        253         29          37
# 266       2012        NaN        286        230         25          52
# 267       2013        NaN        271        229         30          31
# 268       2014        NaN        237        200         27          31
# 269       2015        NaN        280        253         23          42
# 270       2016        NaN        397        323         46          44
# 271       2017        NaN        437        415         29          55
# 272  Sub total        NaN       2900       2396        276         397
# ...

# %%
crash[424:470]
# Out:
#                   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 424                     TIME       2008       2009       2010       2011
# 425            00:01 – 02:00         27         37         29         25
# 426            02:01 – 04:00         21         19         19         20
# 427            04:01 – 06:00         23         36         34         21
# 428            06:01 – 08:00         22         32         26         54
# 429            08:01 – 10:00         27         26         18         27
# 430            10:01 – 12:00         22         29         18         24
# 431            12:01 – 14:00         39         34         37         24
# 432            14:01 – 16:00         51         56         41         58
# 433            16:01 – 18:00         63         48         46         52
# 434            18:01 – 20:00         57         75         63         74
# 435            20:01 – 22:00         58         45         40         52
# ...

# %%
df7 = crash[425:437]
df8 = crash[439:451]
df8.shape
# Out:
# (12, 12)

# %%
df7.drop('Unnamed: 11', axis = 1, inplace = True)
df8.drop('Unnamed: 11', axis = 1, inplace = True)
# Out:
# /var/folders/3x/3hmskxq57hsfkxh4yjqzhn_m0000gn/T/ipykernel_1132/1985054138.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7.drop('Unnamed: 11', axis = 1, inplace = True)
# /var/folders/3x/3hmskxq57hsfkxh4yjqzhn_m0000gn/T/ipykernel_1132/1985054138.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df8.drop('Unnamed: 11', axis = 1, inplace = True)

# %%
df8.shape
# Out:
# (12, 11)

# %%
col_name_df7_df8 = ['TIME', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017']
df7.columns = col_name_df7_df8
df8.columns = col_name_df7_df8

# %%
df8
# Out:
#               TIME 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
# 439  00:01 – 02:00  113   91   59   60   81   78   82  110   69   74
# 440  02:01 – 04:00   52   42   53   38   60   47   45   36   60   63
# 441  04:01 – 06:00   42   75   48   52   49   55   45   47   72   50
# 442  06:01 – 08:00  104  132   90  106  104   68   83   99   78   85
# 443  08:01 – 10:00   82   83   61   75   79   93   63   44   77   54
# 444  10:01 – 12:00   88   91   94   91   87   90   60  100   83   55
# 445  12:01 – 14:00  139  120  126   78  144   81  119  114   85   90
# 446  14:01 – 16:00  169  165  135  151  142  143  114  188   99  118
# 447  16:01 – 18:00  213  220  133  136  142  173  136  163  178  132
# 448  18:01 – 20:00  229  238  203  175  195  199  226  174  205  177
# 449  20:01 – 22:00  179  164  156  157   97  158  150  157  142  144
# 450  22:01 – 00:00  112  119   94  120  105  123  111  132   95  110

# %%
df7_ind = df7.set_index("TIME")
df8_ind = df8.set_index("TIME")

year7 = list(df7_ind.iloc[:,0:].columns)
year8 = list(df8_ind.iloc[:,0:].columns)

df7_long = pd.melt(df7_ind, value_vars=year7, var_name="Year", value_name="Fatalities", ignore_index=False)
df8_long = pd.melt(df8_ind, value_vars=year8, var_name="Year", value_name="Serious Inj", ignore_index=False)

df7_long.reset_index(drop=False, inplace=True)
df8_long.reset_index(drop=False, inplace=True)

# %%
df7_df8 = df7_long.merge(df8_long, how='inner', on=["TIME","Year"])
df7_df8
# Out:
#               TIME  Year Fatalities Serious Inj
# 0    00:01 – 02:00  2008         27         113
# 1    02:01 – 04:00  2008         21          52
# 2    04:01 – 06:00  2008         23          42
# 3    06:01 – 08:00  2008         22         104
# 4    08:01 – 10:00  2008         27          82
# ..             ...   ...        ...         ...
# 115  14:01 – 16:00  2017         36         118
# 116  16:01 – 18:00  2017         36         132
# 117  18:01 – 20:00  2017         75         177
# 118  20:01 – 22:00  2017         61         144
# 119  22:01 – 00:00  2017         52         110
#
# [120 rows x 4 columns]

# %%
df7_df8.to_csv("crashes_2008_2017_by_hour.csv", index = False)

# %%
df9 = crash[453:461]
col9 = ['Day', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017']
df9.drop('Unnamed: 11', axis = 1, inplace = True)
df9.columns = col9
df9
# Out:
# /var/folders/3x/3hmskxq57hsfkxh4yjqzhn_m0000gn/T/ipykernel_1132/146407240.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df9.drop('Unnamed: 11', axis = 1, inplace = True)
#            Day  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017
# 453        Day  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017
# 454     Sunday  2844  2722  2494  2365  2360  2400  2316  2405  2425  2581
# 455     Monday  2632  2666  2501  2386  2371  2145  2093  2289  2483  2282
# 456    Tuesday  2642  2497  2379  2298  2252  2074  2087  2182  2231  2195
# 457  Wednesday  2603  2567  2506  2343  2200  2189  2102  2233  2231  2085
# 458   Thursday  2599  2818  2608  2343  2329  2314  2259  2348  2457  2265
# 459     Friday  3502  3344  3210  3138  2909  2856  2827  2947  3221  3011
# ...

# %%
df9_ind = df9.set_index("Day")
year9 = list(df9_ind.iloc[:,0:].columns)
df9_long = pd.melt(df9_ind, value_vars=year9, var_name="Year", value_name="Crashes_number", ignore_index=False)
df9_long.reset_index(drop=False, inplace=True)
df9_long
# Out:
#           Day  Year Crashes_number
# 0         Day  2008           2008
# 1      Sunday  2008           2844
# 2      Monday  2008           2632
# 3     Tuesday  2008           2642
# 4   Wednesday  2008           2603
# ..        ...   ...            ...
# 75    Tuesday  2017           2195
# 76  Wednesday  2017           2085
# 77   Thursday  2017           2265
# 78     Friday  2017           3011
# 79   Saturday  2017           3367
#
# [80 rows x 3 columns]

# %%
df9.to_csv("crashes_2008_2017_by_day.csv", index = False)

# %%
df10_part1 = crash[465:481]
df10_part2 = crash[481:494]

# %%
df10_part1.drop(['Unnamed: 9', 'Casul','Unnamed: 10', 'Unnamed: 11'], axis = 1, inplace = True)
df10_part2.drop(['Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11'], axis = 1, inplace = True)
# Out:
# /var/folders/3x/3hmskxq57hsfkxh4yjqzhn_m0000gn/T/ipykernel_1132/114617865.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df10_part1.drop(['Unnamed: 9', 'Casul','Unnamed: 10', 'Unnamed: 11'], axis = 1, inplace = True)
# /var/folders/3x/3hmskxq57hsfkxh4yjqzhn_m0000gn/T/ipykernel_1132/114617865.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df10_part2.drop(['Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11'], axis = 1, inplace = True)

# %%
col10_1 = ["Casuality Class", "Year", "Sunday", "Monday", "Tuesday", "W_T", "Friday", "Saturday"]
df10_part1.columns = col10_1
df10_part1[["Wednesday", "Thursday"]] = df10_part1["W_T"].str.split(" ", expand = True)
df10_part1.drop(columns = ["W_T"], axis = 1, inplace = True)
df10_part1
# Out:
# /var/folders/3x/3hmskxq57hsfkxh4yjqzhn_m0000gn/T/ipykernel_1132/251012439.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df10_part1[["Wednesday", "Thursday"]] = df10_part1["W_T"].str.split(" ", expand = True)
# /var/folders/3x/3hmskxq57hsfkxh4yjqzhn_m0000gn/T/ipykernel_1132/251012439.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df10_part1[["Wednesday", "Thursday"]] = df10_part1["W_T"].str.split(" ", expand = True)
# ...

# %%
col10_2 = ["Casuality Class", "Year", "Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"]
df10_part1 = df10_part1[col10_2]

# %%
df10_part2.columns = col10_2

# %%
df10 = pd.concat([df10_part1, df10_part2], ignore_index=True, sort=False)
df10
# Out:
#    Casuality Class  Year Sunday Monday Tuesday Wednesday Thursday Friday  \
# 0       Fatalities  2009    103     52      36        46       62     91
# 1              NaN  2010     76     53      37        40       48     55
# 2              NaN  2011     91     40      53        42       54     85
# 3              NaN  2012    104     35      39        39       24     60
# 4              NaN  2013     98     23      44        45       48     50
# 5              NaN  2014     77     31      30        34       34     77
# 6              NaN  2015     83     34      33        35       57     64
# 7              NaN  2016     86     40      38        33       53     78
# 8              NaN  2017     70     58      41        30       59     58
# 9              NaN   NaN    NaN    NaN     NaN       NaN      NaN    NaN
# 10         Serious  2009    297    158     130       155      167    252
# 11             NaN  2010    238    131     120       131      146    200
# ...

# %%
df10['Casuality Class'].fillna(method='pad',inplace=True)
df10
# Out:
#    Casuality Class  Year Sunday Monday Tuesday Wednesday Thursday Friday  \
# 0       Fatalities  2009    103     52      36        46       62     91
# 1       Fatalities  2010     76     53      37        40       48     55
# 2       Fatalities  2011     91     40      53        42       54     85
# 3       Fatalities  2012    104     35      39        39       24     60
# 4       Fatalities  2013     98     23      44        45       48     50
# 5       Fatalities  2014     77     31      30        34       34     77
# 6       Fatalities  2015     83     34      33        35       57     64
# 7       Fatalities  2016     86     40      38        33       53     78
# 8       Fatalities  2017     70     58      41        30       59     58
# 9       Fatalities   NaN    NaN    NaN     NaN       NaN      NaN    NaN
# 10         Serious  2009    297    158     130       155      167    252
# 11         Serious  2010    238    131     120       131      146    200
# ...

# %%
df10_ind = df10.set_index(["Casuality Class", "Year"])
day10 = list(df10_ind.iloc[:,0:].columns)
df10_long = pd.melt(df10_ind, value_vars=day10, var_name="Day", value_name="Casualties", ignore_index=False)
df10_long.reset_index(drop=False, inplace=True)
df10_long
# Out:
#     Casuality Class  Year       Day Casualties
# 0        Fatalities  2009    Sunday        103
# 1        Fatalities  2010    Sunday         76
# 2        Fatalities  2011    Sunday         91
# 3        Fatalities  2012    Sunday        104
# 4        Fatalities  2013    Sunday         98
# ..              ...   ...       ...        ...
# 198           Minor  2013  Saturday        956
# 199           Minor  2014  Saturday        961
# 200           Minor  2015  Saturday        963
# 201           Minor  2016  Saturday       1100
# 202           Minor  2017  Saturday       1036
#
# [203 rows x 4 columns]

# %%
df10_long.to_csv("crashes_2008_2017_by_day_by_severity.csv", index = False)

# %%
df11_1 = crash.iloc[498:507, 0:6]
df11_2 = crash.iloc[508:523, 0:7]
df11_3 = crash.iloc[523:527, 0:6]
col11 = ['Casualty Class', 'Year', 'Daylight', 'Dusk', 'Night Street lit', 'Night bright moon', 'Dark']

# %%
df11_1[['Dusk', 'Night Street lit']] = df11_1['Unnamed: 3'].str.split(" ", expand = True)
df11_1.drop(columns = ["Unnamed: 3"], axis = 1, inplace = True)
df11_1.columns = [['Casualty Class', 'Year', 'Daylight', 'Night bright moon', 'Dark', 'Dusk', 'Night Street lit']]

# %%
df11_1['Casualty Class'] = 'Fatalities'
df11_1 = df11_1[col11]

# %%
df11_2.columns = col11

# %%
df11_2.iloc[0,3] = 29
df11_2.iloc[0,4] = 144
df11_2.iloc[0,5] = 51
df11_2.iloc[0,6] = 551
df11_2['Casualty Class'].fillna(method = 'pad', inplace=True)
df11_2
# Out:
#        Casualty Class  Year Daylight Dusk Night Street lit Night bright moon  \
# 508  Serious Injuries  2009      765   29              144                51
# 509  Serious Injuries  2010      658   25               97                36
# 510  Serious Injuries  2011      700    0               92                18
# 511  Serious Injuries  2012      754    0              115                18
# 512  Serious Injuries  2013      693    0              129                23
# 513  Serious Injuries  2014      661    0              120                 9
# 514  Serious Injuries  2015      769    0              142                24
# 515  Serious Injuries  2016      638    0              114                 8
# 516  Serious Injuries  2017      538    0              144                11
# 517  Serious Injuries   NaN      NaN  NaN              NaN               NaN
# 518    Minor Injuries  2009     4026  115              493                90
# ...

# %%
df11_2.dropna(inplace=True)

# %%
df11_3.columns = ['Year', 'Daylight', 'Dusk', 'Night Street lit', 'Night bright moon', 'Dark']
df11_3['Casualty Class'] = 'Minor Injuries'
df11_3 = df11_3[col11]
df11_3
# Out:
#      Casualty Class  Year Daylight Dusk Night Street lit Night bright moon  \
# 523  Minor Injuries  2014     2632    0              507                21
# 524  Minor Injuries  2015     2655    0              520                55
# 525  Minor Injuries  2016     2918    0              582                60
# 526  Minor Injuries  2017     2540    0              664                50
#
#      Dark
# 523  1294
# 524  1298
# 525  1434
# 526  1485

# %%
df11_2_3 = pd.concat([df11_2, df11_3], ignore_index=True, sort=False)
df11_2_3.to_csv("df11_2_3.csv", index = False)
df11_1.to_csv("df11_1.csv", index = False)

# %%
df11_2_3 = pd.read_csv("df11_2_3.csv")
df11_1 = pd.read_csv("df11_1.csv")

# %%
df11 = pd.concat([df11_1, df11_2_3])
df11
# Out:
#       Casualty Class  Year  Daylight  Dusk  Night Street lit  \
# 0         Fatalities  2009       236    14                34
# 1         Fatalities  2010       196    11                19
# 2         Fatalities  2011       259     0                38
# 3         Fatalities  2012       227     0                43
# 4         Fatalities  2013       183     0                35
# 5         Fatalities  2014       174     0                48
# 6         Fatalities  2015       174     0                55
# 7         Fatalities  2016       228     0                34
# 8         Fatalities  2017       179     0                42
# 0   Serious Injuries  2009       765    29               144
# 1   Serious Injuries  2010       658    25                97
# 2   Serious Injuries  2011       700     0                92
# 3   Serious Injuries  2012       754     0               115
# 4   Serious Injuries  2013       693     0               129
# ...

# %%
df11_ind = df11.set_index(['Casualty Class', 'Year'])
year11 = list(df11_ind.iloc[:,0:].columns)
df11_long = pd.melt(df11_ind, value_vars=year11, var_name="Day Time", value_name="Crash Casualty", ignore_index=False)
df11_long.reset_index(drop=False, inplace=True)
df11_long
# Out:
#      Casualty Class  Year  Day Time  Crash Casualty
# 0        Fatalities  2009  Daylight             236
# 1        Fatalities  2010  Daylight             196
# 2        Fatalities  2011  Daylight             259
# 3        Fatalities  2012  Daylight             227
# 4        Fatalities  2013  Daylight             183
# ..              ...   ...       ...             ...
# 130  Minor Injuries  2013      Dark            1420
# 131  Minor Injuries  2014      Dark            1294
# 132  Minor Injuries  2015      Dark            1298
# 133  Minor Injuries  2016      Dark            1434
# 134  Minor Injuries  2017      Dark            1485
#
# [135 rows x 4 columns]

# %%
df11_long.to_csv("crashes_2009_2017_by_daytime.csv", index = False)

# %%
crash[529:550]
# Out:
#                Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 529  Number of Fatalities        NaN        NaN        NaN        NaN
# 530        Age Group 2012       2013       2014       2015       2016
# 531              01-05 24         26         19         16         21
# 532              06-10 20         13          9         11         11
# 533               11-15 4          8          4          3         11
# 534              16-20 17         21         19         20         21
# 535              21-25 60         40         48         54         55
# 536              26-30 66         83         75         57         67
# 537              31-35 58         61         53         64         66
# 538              36-40 38         41         42         55         63
# 539              41-45 27         24         34         39         35
# 540              46-50 17         27         17         23         24
# ...

# %%
df12 = crash.iloc[531:547, 0:6]
df12
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 531   01-05 24         26         19         16         21         23
# 532   06-10 20         13          9         11         11         13
# 533    11-15 4          8          4          3         11          8
# 534   16-20 17         21         19         20         21         22
# 535   21-25 60         40         48         54         55         39
# 536   26-30 66         83         75         57         67         72
# 537   31-35 58         61         53         64         66         68
# 538   36-40 38         41         42         55         63         53
# 539   41-45 27         24         34         39         35         34
# 540   46-50 17         27         17         23         24         19
# 541   51-55 24         17         11         19         22         22
# 542   56-60 18         20         14         19         20         18
# ...

# %%
df12[['Age Group', '2012']] = df12["Unnamed: 0"].str.split(" ", expand = True)
df12
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 531   01-05 24         26         19         16         21         23
# 532   06-10 20         13          9         11         11         13
# 533    11-15 4          8          4          3         11          8
# 534   16-20 17         21         19         20         21         22
# 535   21-25 60         40         48         54         55         39
# 536   26-30 66         83         75         57         67         72
# 537   31-35 58         61         53         64         66         68
# 538   36-40 38         41         42         55         63         53
# 539   41-45 27         24         34         39         35         34
# 540   46-50 17         27         17         23         24         19
# 541   51-55 24         17         11         19         22         22
# 542   56-60 18         20         14         19         20         18
# ...

# %%
df12.drop(columns = ["Unnamed: 0"], axis = 1, inplace = True)
df12
# Out:
#     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Age Group 2012
# 531         26         19         16         21         23     01-05   24
# 532         13          9         11         11         13     06-10   20
# 533          8          4          3         11          8     11-15    4
# 534         21         19         20         21         22     16-20   17
# 535         40         48         54         55         39     21-25   60
# 536         83         75         57         67         72     26-30   66
# 537         61         53         64         66         68     31-35   58
# 538         41         42         55         63         53     36-40   38
# 539         24         34         39         35         34     41-45   27
# 540         27         17         23         24         19     46-50   17
# 541         17         11         19         22         22     51-55   24
# 542         20         14         19         20         18     56-60   18
# ...

# %%
col12 = ['Age Group', '2012', '2013', '2014', '2015', '2016', '2017']

# %%
df12.columns = ['2013', '2014', '2015', '2016', '2017', 'Age Group', '2012']
df12 = df12[col12]
df12
# Out:
#     Age Group 2012 2013 2014 2015 2016 2017
# 531     01-05   24   26   19   16   21   23
# 532     06-10   20   13    9   11   11   13
# 533     11-15    4    8    4    3   11    8
# 534     16-20   17   21   19   20   21   22
# 535     21-25   60   40   48   54   55   39
# 536     26-30   66   83   75   57   67   72
# 537     31-35   58   61   53   64   66   68
# 538     36-40   38   41   42   55   63   53
# 539     41-45   27   24   34   39   35   34
# 540     46-50   17   27   17   23   24   19
# 541     51-55   24   17   11   19   22   22
# 542     56-60   18   20   14   19   20   18
# 543     61-65    8    5   10    8    9   19
# 544     66-70   10    8   11   15    9   16
# 545     71-75    7   10    6    2    6    4
# 546       >75    6    7    5    6   10   14

# %%
df12_ind = df12.set_index('Age Group')
year12 = list(df12_ind.iloc[:,0:].columns)
df12_long = pd.melt(df12_ind, value_vars=year12, var_name="Year", value_name="Fatalities", ignore_index=False)
df12_long.reset_index(drop=False, inplace=True)
df12_long
# Out:
#    Age Group  Year Fatalities
# 0      01-05  2012         24
# 1      06-10  2012         20
# 2      11-15  2012          4
# 3      16-20  2012         17
# 4      21-25  2012         60
# ..       ...   ...        ...
# 91     56-60  2017         18
# 92     61-65  2017         19
# 93     66-70  2017         16
# 94     71-75  2017          4
# 95       >75  2017         14
#
# [96 rows x 3 columns]

# %%
df12_long.to_csv('crashes_2012_2017_by_age.csv', index = False)

# %%
crash[642:670]
# Out:
#         Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 642  asualty Class       Year       Year     Driver     Driver  Passenger
# 643     Fatalities       2012       2012        115        115        184
# 644            NaN       2013       2013         98         98        201
# 645            NaN       2014       2014         97         97        186
# 646      atalities        NaN        NaN        NaN        NaN        NaN
# 647            NaN       2015       2015        116        116        175
# 648            NaN       2016       2016        128        128        211
# 649            NaN       2017       2017        126        126        176
# 650        Serious       2012       2012        316        316        623
# 651            NaN       2013       2013        344        344        698
# 652            NaN       2014       2014        324        324        630
# 653         erious        NaN        NaN        NaN        NaN        NaN
# ...

# %%
df13 = crash.iloc[643:664,0:8]
df13.drop(columns = ["Unnamed: 2", "Unnamed: 4", "Unnamed: 6"], axis = 1, inplace = True)
df13
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 3 Unnamed: 5 Unnamed: 7
# 643  Fatalities       2012        115        184        105
# 644         NaN       2013         98        201        112
# 645         NaN       2014         97        186         94
# 646   atalities        NaN        NaN        NaN        NaN
# 647         NaN       2015        116        175        120
# 648         NaN       2016        128        211        111
# 649         NaN       2017        126        176        142
# 650     Serious       2012        316        623        346
# 651         NaN       2013        344        698        266
# 652         NaN       2014        324        630        280
# 653      erious        NaN        NaN        NaN        NaN
# 654         NaN       2015        324        743        297
# 655         NaN       2016        353        609        281
# 656         NaN       2017        315        543        294
# 657         NaN       2012       1448       1964        934
# ...

# %%
df13.columns = ['Casualty Class', 'Year', 'Driver', 'Passenger', 'Pedestrian']
df13.iloc[-5, 4] = 973
df13.iloc[-3, 4] = 1005
df13.iloc[-2, 4] = 1049
df13.iloc[-1, 4] = 1012
df13
# Out:
#     Casualty Class  Year Driver Passenger Pedestrian
# 643     Fatalities  2012    115       184        105
# 644            NaN  2013     98       201        112
# 645            NaN  2014     97       186         94
# 646      atalities   NaN    NaN       NaN        NaN
# 647            NaN  2015    116       175        120
# 648            NaN  2016    128       211        111
# 649            NaN  2017    126       176        142
# 650        Serious  2012    316       623        346
# 651            NaN  2013    344       698        266
# 652            NaN  2014    324       630        280
# 653         erious   NaN    NaN       NaN        NaN
# 654            NaN  2015    324       743        297
# 655            NaN  2016    353       609        281
# 656            NaN  2017    315       543        294
# 657            NaN  2012   1448      1964        934
# 658            NaN  2013   1454      2011        973
# 659           2014  2014   1439      2042        973
# ...

# %%
df13['Casualty Class'].fillna(method = 'pad', inplace=True)

# %%
df13.dropna(inplace = True)
df13
# Out:
#     Casualty Class  Year Driver Passenger Pedestrian
# 643     Fatalities  2012    115       184        105
# 644     Fatalities  2013     98       201        112
# 645     Fatalities  2014     97       186         94
# 647      atalities  2015    116       175        120
# 648      atalities  2016    128       211        111
# 649      atalities  2017    126       176        142
# 650        Serious  2012    316       623        346
# 651        Serious  2013    344       698        266
# 652        Serious  2014    324       630        280
# 654         erious  2015    324       743        297
# 655         erious  2016    353       609        281
# 656         erious  2017    315       543        294
# 657         erious  2012   1448      1964        934
# 658         erious  2013   1454      2011        973
# 659           2014  2014   1439      2042        973
# 661           2015  2015   1483      2040       1005
# 662           2016  2016   1668      2277       1049
# ...

# %%
df13.iloc[3:6,0] = 'Fatalities'
df13.iloc[9:12,0] = 'Serious'
df13.iloc[12:,0] = 'Minor'
df13
# Out:
#     Casualty Class  Year Driver Passenger Pedestrian
# 643     Fatalities  2012    115       184        105
# 644     Fatalities  2013     98       201        112
# 645     Fatalities  2014     97       186         94
# 647     Fatalities  2015    116       175        120
# 648     Fatalities  2016    128       211        111
# 649     Fatalities  2017    126       176        142
# 650        Serious  2012    316       623        346
# 651        Serious  2013    344       698        266
# 652        Serious  2014    324       630        280
# 654        Serious  2015    324       743        297
# 655        Serious  2016    353       609        281
# 656        Serious  2017    315       543        294
# 657          Minor  2012   1448      1964        934
# 658          Minor  2013   1454      2011        973
# 659          Minor  2014   1439      2042        973
# 661          Minor  2015   1483      2040       1005
# 662          Minor  2016   1668      2277       1049
# ...

# %%
df13_ind = df13.set_index(['Casualty Class', 'Year'])
participant = list(df13_ind.iloc[:,0:].columns)
df13_long = pd.melt(df13_ind, value_vars=participant, var_name="Participant", value_name="Casualties", ignore_index=False)
df13_long.reset_index(drop=False, inplace=True)
df13_long
# Out:
#    Casualty Class  Year Participant Casualties
# 0      Fatalities  2012      Driver        115
# 1      Fatalities  2013      Driver         98
# 2      Fatalities  2014      Driver         97
# 3      Fatalities  2015      Driver        116
# 4      Fatalities  2016      Driver        128
# 5      Fatalities  2017      Driver        126
# 6         Serious  2012      Driver        316
# 7         Serious  2013      Driver        344
# 8         Serious  2014      Driver        324
# 9         Serious  2015      Driver        324
# 10        Serious  2016      Driver        353
# 11        Serious  2017      Driver        315
# 12          Minor  2012      Driver       1448
# 13          Minor  2013      Driver       1454
# 14          Minor  2014      Driver       1439
# 15          Minor  2015      Driver       1483
# 16          Minor  2016      Driver       1668
# 17          Minor  2017      Driver       1670
# 18     Fatalities  2012   Passenger        184
# ...

# %%
df13_long.to_csv('crashes_2012_2017_by_participant.csv', index = False)

# %%
crash[800:830]
# Out:
#      Unnamed: 0 Unnamed: 1   Unnamed: 2 Unnamed: 3  \
# 800      Kasane         19  12 12 25 16         26
# 801     Foreign         57  22 24 42 26         21
# 802       Month       2012         2013       2014
# 803     January      20905        40000      26900
# 804    February      38161        30471      30708
# 805       March      39249        26731      36109
# 806       April      36899        36413      32954
# 807         May      43495        41924      57826
# 808        June      56535        36150      34273
# 809        July   44308.28        43448      41254
# 810      August   49966.14        43268      57287
# 811   September    54583.6        23855      50850
# 812     October   47844.28        43225      73900
# 813    November   44500.14        30640      39700
# 814    December   35904.14        27630      46468
# 815       Total     512351       423755     528229
# 816     Station  1995-2012         2013       2014
# ...

# %%
df14 = crash.iloc[803:815, 0:7]
df14
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 803    January      20905      40000      26900      42274      35320
# 804   February      38161      30471      30708      33090      40131
# 805      March      39249      26731      36109      43909      43992
# 806      April      36899      36413      32954      31728      32415
# 807        May      43495      41924      57826      37020      55014
# 808       June      56535      36150      34273      37670      48175
# 809       July   44308.28      43448      41254      28075      33915
# 810     August   49966.14      43268      57287      77005      36430
# 811  September    54583.6      23855      50850      44935      43136
# 812    October   47844.28      43225      73900      41262      38104
# 813   November   44500.14      30640      39700      47905      27410
# 814   December   35904.14      27630      46468      46905      37917
#
#     Unnamed: 6
# 803      21825
# 804      22850
# ...

# %%
df14.columns = ['Month', '2012', '2013', '2014', '2015', '2016', '2017']
df14
# Out:
#          Month      2012   2013   2014   2015   2016   2017
# 803    January     20905  40000  26900  42274  35320  21825
# 804   February     38161  30471  30708  33090  40131  22850
# 805      March     39249  26731  36109  43909  43992  24500
# 806      April     36899  36413  32954  31728  32415  19020
# 807        May     43495  41924  57826  37020  55014  20600
# 808       June     56535  36150  34273  37670  48175  19000
# 809       July  44308.28  43448  41254  28075  33915  14300
# 810     August  49966.14  43268  57287  77005  36430  21640
# 811  September   54583.6  23855  50850  44935  43136  12520
# 812    October  47844.28  43225  73900  41262  38104  14200
# 813   November  44500.14  30640  39700  47905  27410  12350
# 814   December  35904.14  27630  46468  46905  37917  14470

# %%
df14_ind = df14.set_index("Month")
year14 = list(df14_ind.iloc[:,0:].columns)
df14_long = pd.melt(df14_ind, value_vars=year14, var_name="Year", value_name="BWP", ignore_index=False)
df14_long.reset_index(drop=False, inplace=True)
df14_long
# Out:
#         Month  Year    BWP
# 0     January  2012  20905
# 1    February  2012  38161
# 2       March  2012  39249
# 3       April  2012  36899
# 4         May  2012  43495
# ..        ...   ...    ...
# 67     August  2017  21640
# 68  September  2017  12520
# 69    October  2017  14200
# 70   November  2017  12350
# 71   December  2017  14470
#
# [72 rows x 3 columns]

# %%
df14_long.to_csv('BWP_2012_2017_by_month.csv', index = False)

# %%
crash[815:850]
# Out:
#            Unnamed: 0             Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 815             Total                 512351     423755     528229     511778
# 816           Station              1995-2012       2013       2014       2015
# 817           DRTS Hq                  77603       6666       7615       6386
# 818             Kanye                   7600        112        249        216
# 819           Palapye                   9618        561        556        654
# 820              Maun                  16059       1544       1370       1360
# 821           Lobatse                  26567       3404       1755       1762
# 822         Mahalapye                   9902        453        489        564
# 823           Tsabong                   1672         43         31         41
# 824            Kasane                   3171        252        192        108
# 825        Molepolole                   4607        215        318        261
# ...

# %%
df15 = crash.iloc[817:847,0:7]
col15 = ['Station', '1995-2012', '2013', '2014', '2015', '2016', '2017']
df15.columns = col15
df15
# Out:
#               Station 1995-2012  2013  2014   2015   2016   2017
# 817           DRTS Hq     77603  6666  7615   6386   8054  10820
# 818             Kanye      7600   112   249    216    167    252
# 819           Palapye      9618   561   556    654    734    802
# 820              Maun     16059  1544  1370   1360   1322   1463
# 821           Lobatse     26567  3404  1755   1762   1632   2148
# 822         Mahalapye      9902   453   489    564    560    558
# 823           Tsabong      1672    43    31     41     61     63
# 824            Kasane      3171   252   192    108    130    115
# 825        Molepolole      4607   215   318    261    255   1101
# 826          S/Phikwe     21364  1071  1120   1157   1027    943
# 827        Letlhakane      4012   292   258    269    255    251
# 828            Serowe      8960   546   618    589    589    615
# 829          Ramotswa      5238   694  1262   1281   1454   1601
# ...

# %%
df15_ind = df15.set_index(["Station"])
year15 = list(df15_ind.iloc[:,0:].columns)
df15_long = pd.melt(df15_ind, value_vars=year15, var_name="Year", value_name="Number of Registered Vehicles", ignore_index=False)
df15_long.reset_index(drop=False, inplace=True)
df15_long
# Out:
#               Station       Year Number of Registered Vehicles
# 0             DRTS Hq  1995-2012                         77603
# 1               Kanye  1995-2012                          7600
# 2             Palapye  1995-2012                          9618
# 3                Maun  1995-2012                         16059
# 4             Lobatse  1995-2012                         26567
# ..                ...        ...                           ...
# 175           Masunga       2017                            12
# 176           Shakawe       2017                            11
# 177       Gaborone IV       2017                           NaN
# 178  F/Town G/ Valley       2017                          3147
# 179      Old Supplies       2017                          1437
#
# [180 rows x 3 columns]

# %%
df15_long.to_csv('vehicles_1995_2017.csv', index = False)

# %%
df16_1 = crash.iloc[850:895,0:9]
df16_2 = crash.iloc[896:913,0:8]

# %%
col16 = ['Cause of Crash', 'Causes of Car Crashes', '2010', '2011', '2012', '2013', '2014', '2015', '2016']
df16_1.columns = col16
df16_1
# Out:
#     Cause of Crash                    Causes of Car Crashes  2010  2011  2012  \
# 850        Drivers           Following to close from behind  1862  2281  2532
# 851        Drivers                    Reversing negligently  1563  1363  1373
# 852        Drivers                           Losing Control  1204  1382  1422
# 853        Drivers   Failing to comply with traffic sign or   710   631   703
# 854        Drivers                                   signal   NaN   NaN   NaN
# 855        Drivers                        Unlicensed driver   590   569   553
# 856        Drivers             Influence of drinks or drugs   492   429   518
# 857        Drivers                    Overtaking improperly   423   427   401
# 858        Drivers                            Over speeding   384   269   268
# 859        Drivers                     Turning without care   297   264   156
# 860        Drivers                              U - turning   135   116   108
# ...

# %%
df16_2.iloc[0,5] = '160 127'
df16_2.iloc[5,5] = '0 0'
df16_2.iloc[8,5] = '50 76'
df16_2.iloc[10,5] = '27 37'
df16_2.iloc[-4,5] = '4 5'
df16_2.iloc[-1,5] = '2 1'
df16_2.dropna(inplace = True)
# Out:
#        Unnamed: 0                         Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 896  Obstructions                 Other obstructions        167        157
# 897       Defects                         Tyre burst        222        181
# 898       Defects  Defect unattended vehicle running         11         19
# 901       Defects                 Physical defective          8          0
# 903       Defects                      Other defects        249        171
# 904       Weather                  Road surface type         81         95
# 906       Weather                    Roads pot holes         58         33
# 907       Weather                         Heavy rain         13          8
# 909       Weather                        Strong wind          6          3
# 911       Weather              Other weather factors         11         15
# 912       Weather    Use of Cell phone while driving          7          3
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7
# ...

# %%
df16_2[["2013", "2014"]] = df16_2["Unnamed: 5"].str.split(" ", expand = True)
df16_2
# Out:
#        Unnamed: 0                         Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 896  Obstructions                 Other obstructions        167        157
# 897       Defects                         Tyre burst        222        181
# 898       Defects  Defect unattended vehicle running         11         19
# 901       Defects                 Physical defective          8          0
# 903       Defects                      Other defects        249        171
# 904       Weather                  Road surface type         81         95
# 906       Weather                    Roads pot holes         58         33
# 907       Weather                         Heavy rain         13          8
# 909       Weather                        Strong wind          6          3
# 911       Weather              Other weather factors         11         15
# 912       Weather    Use of Cell phone while driving          7          3
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 2013 2014
# ...

# %%
df16_2.drop(columns = ["Unnamed: 5"], axis = 1, inplace = True)
df16_2.columns = ['Cause of Crash', 'Causes of Car Crashes', '2010', '2011', '2012', '2015', '2016', '2013', '2014',]
df16_2 = df16_2[col16]
df16_2
# Out:
#     Cause of Crash              Causes of Car Crashes 2010 2011 2012 2013  \
# 896   Obstructions                 Other obstructions  167  157  169  160
# 897        Defects                         Tyre burst  222  181  163  136
# 898        Defects  Defect unattended vehicle running   11   19    7    0
# 901        Defects                 Physical defective    8    0    2    0
# 903        Defects                      Other defects  249  171  162  174
# 904        Weather                  Road surface type   81   95   60   50
# 906        Weather                    Roads pot holes   58   33   23   27
# 907        Weather                         Heavy rain   13    8    4    1
# 909        Weather                        Strong wind    6    3    4    4
# 911        Weather              Other weather factors   11   15   11    3
# 912        Weather    Use of Cell phone while driving    7    3    1    2
#
#     2014 2015 2016
# 896  127  167  124
# 897  133  138  126
# ...

# %%
df16 = pd.concat([df16_1, df16_2])
df16
# Out:
#     Cause of Crash                    Causes of Car Crashes  2010  2011  2012  \
# 850        Drivers           Following to close from behind  1862  2281  2532
# 851        Drivers                    Reversing negligently  1563  1363  1373
# 852        Drivers                           Losing Control  1204  1382  1422
# 853        Drivers   Failing to comply with traffic sign or   710   631   703
# 854        Drivers                                   signal   NaN   NaN   NaN
# 855        Drivers                        Unlicensed driver   590   569   553
# 856        Drivers             Influence of drinks or drugs   492   429   518
# 857        Drivers                    Overtaking improperly   423   427   401
# 858        Drivers                            Over speeding   384   269   268
# 859        Drivers                     Turning without care   297   264   156
# 860        Drivers                              U - turning   135   116   108
# ...

# %%
df16.dropna(subset=['2010', '2011'], inplace=True)
df16
# Out:
#     Cause of Crash                    Causes of Car Crashes  2010  2011  2012  \
# 850        Drivers           Following to close from behind  1862  2281  2532
# 851        Drivers                    Reversing negligently  1563  1363  1373
# 852        Drivers                           Losing Control  1204  1382  1422
# 853        Drivers   Failing to comply with traffic sign or   710   631   703
# 855        Drivers                        Unlicensed driver   590   569   553
# 856        Drivers             Influence of drinks or drugs   492   429   518
# 857        Drivers                    Overtaking improperly   423   427   401
# 858        Drivers                            Over speeding   384   269   268
# 859        Drivers                     Turning without care   297   264   156
# 860        Drivers                              U - turning   135   116   108
# 861        Drivers                       Fatigued or asleep    83    59    67
# ...

# %%
df16_ind = df16.set_index(["Cause of Crash", "Causes of Car Crashes"])
year16 = list(df16_ind.iloc[:,0:].columns)
df16_long = pd.melt(df16_ind, value_vars=year16, var_name="Year", value_name="Casualty", ignore_index=False)
df16_long.reset_index(drop=False, inplace=True)
df16_long
# Out:
#     Cause of Crash                   Causes of Car Crashes  Year Casualty
# 0          Drivers          Following to close from behind  2010     1862
# 1          Drivers                   Reversing negligently  2010     1563
# 2          Drivers                          Losing Control  2010     1204
# 3          Drivers  Failing to comply with traffic sign or  2010      710
# 4          Drivers                       Unlicensed driver  2010      590
# ..             ...                                     ...   ...      ...
# 366        Weather                         Roads pot holes  2016       26
# 367        Weather                              Heavy rain  2016       11
# 368        Weather                             Strong wind  2016        2
# 369        Weather                   Other weather factors  2016        2
# 370        Weather         Use of Cell phone while driving  2016        1
#
# [371 rows x 4 columns]

# %%
df16_long.to_csv('crashes_2010_2016_summary.csv', index = False)
